# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from matplotlib_venn import venn2, venn2_circles, venn2_unweighted
from matplotlib.colors import LogNorm

from astropy.table import Table
from astropy import utils, io
import astropy.io.fits as fits
from astropy import constants as const
import astropy.units as u
from astropy.utils.data import download_file
from astropy.coordinates import SkyCoord
from astropy.cosmology import WMAP9 as cosmo
from astropy.cosmology import FlatLambdaCDM
from astropy.wcs import WCS
from astropy.io import ascii
from astroquery.skyview import SkyView
from astropy.visualization import make_lupton_rgb
from astropy.utils.exceptions import AstropyWarning
import warnings
warnings.simplefilter('ignore', category=AstropyWarning) # to quiet Astropy warnings

from CutOuts import main

# %%
# main('/Volumes/Auge_Backup/GOODS Images/hlsp_candels_hst_wfc3_gs-tot_f125w_v1.0_drz.fits',
     # goodsS_z[482], goodsS_RA[482], goodsS_Dec[482], 'deg',goodsS_ID[482])

main('/Users/connorauge/Downloads/BAT_998.fits',0.046,'18:45:26.2566','72:11:01.046','hms','BASS998_3kpc',phys_size=3)
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 283.6363636363636  70.0
# CRPIX : -61020.0  -195268.0
# CD1_1 CD1_2  : -1.1111111111111e-05  0.0
# CD2_1 CD2_2  : 0.0  1.11111111111111e-05
# NAXIS : 5884  5334
# 3

# %%
main('/Users/connorauge/Downloads/BAT_998.fits',0.046,'18:45:26.2566','72:11:01.046','hms','physical',100,0.05,'BASS998_test',1)

img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS998_test.fits')

img[np.isnan(img)] = 0
plt.imshow(img,norm=LogNorm(vmin=0.01,vmax=np.nanmax(img)+1),cmap='gray')
# plt.colorbar()
# plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS998_50kpc.pdf')
# plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 283.6363636363636  70.0
# CRPIX : -61020.0  -195268.0
# CD1_1 CD1_2  : -1.1111111111111e-05  0.0
# CD2_1 CD2_2  : 0.0  1.11111111111111e-05
# NAXIS : 5884  5334

# %%
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS998_5kpc.fits')

img[np.isnan(img)] = 0
plt.imshow(img,norm=LogNorm(vmin=np.nanmin(img[img != 0]),vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS998_5kpc.pdf')
plt.close()

# %%
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS998_3kpc.fits')

img[np.isnan(img)] = 0
plt.imshow(img,norm=LogNorm(vmin=np.nanmin(img[img != 0]),vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS998_3kpc.pdf')
plt.close()

# %%
main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/ESO383-18_drz.fits',0.01292,203.35877,-34.014805,'deg','BASS677_50kpc',phys_size=50)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS677_50kpc.fits')

img[np.isnan(img)] = 0
plt.imshow(img,norm=LogNorm(vmin=0.01,vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS677_50kpc.pdf')
plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 203.3613018597269  -34.02920179748104
# CRPIX : 2108.0  2122.5
# CD1_1 CD1_2  : -1.3848045396705e-05  -1.0643651904712e-06
# CD2_1 CD2_2  : -1.0643651904712e-06  1.38480453967054e-05
# NAXIS : 4216  4245
# 50

# %%
main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/ESO383-18_drz.fits',0.01292,203.35877,-34.014805,'deg','BASS677_5kpc',phys_size=5)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS677_5kpc.fits')

img[np.isnan(img)] = 0
plt.imshow(img,norm=LogNorm(vmin=0.01,vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS677_5kpc.pdf')
plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 203.3613018597269  -34.02920179748104
# CRPIX : 2108.0  2122.5
# CD1_1 CD1_2  : -1.3848045396705e-05  -1.0643651904712e-06
# CD2_1 CD2_2  : -1.0643651904712e-06  1.38480453967054e-05
# NAXIS : 4216  4245
# 5

# %%
main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/ESO383-18_drz.fits',0.01292,203.35877,-34.014805,'deg','BASS677_3kpc',phys_size=3)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS677_3kpc.fits')

img[np.isnan(img)] = 0
plt.imshow(img,norm=LogNorm(vmin=np.nanmin(img[img != 0]),vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS677_3kpc.pdf')
plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 203.3613018597269  -34.02920179748104
# CRPIX : 2108.0  2122.5
# CD1_1 CD1_2  : -1.3848045396705e-05  -1.0643651904712e-06
# CD2_1 CD2_2  : -1.0643651904712e-06  1.38480453967054e-05
# NAXIS : 4216  4245
# 3

# %%
main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/MCG+11-11-32_drz.fits',0.03600,133.802422,64.395949,'deg','BASS434_50kpc',phys_size=50)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS434_50kpc.fits')
img[np.isnan(img)] = 0

plt.imshow(img,norm=LogNorm(vmin=0.01,vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS434_50kpc.pdf')
plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 133.8204148294566  64.4083221617287
# CRPIX : 2108.5  2121.5
# CD1_1 CD1_2  : 1.11606843645179e-05  -8.2668227925549e-06
# CD2_1 CD2_2  : -8.2668227925549e-06  -1.1160684364517e-05
# NAXIS : 4217  4243
# 50

# %%
main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/MCG+11-11-32_drz.fits',0.03600,133.802422,64.395949,'deg','BASS434_5kpc',phys_size=5)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS434_5kpc.fits')
img[np.isnan(img)] = 0

plt.imshow(img,norm=LogNorm(vmin=np.nanmin(img[img != 0]),vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS434_5kpc.pdf')
plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 133.8204148294566  64.4083221617287
# CRPIX : 2108.5  2121.5
# CD1_1 CD1_2  : 1.11606843645179e-05  -8.2668227925549e-06
# CD2_1 CD2_2  : -8.2668227925549e-06  -1.1160684364517e-05
# NAXIS : 4217  4243
# 5

# %%
main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/MCG+11-11-32_drz.fits',0.03600,133.802422,64.395949,'deg','BASS434_3kpc',phys_size=3)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS434_3kpc.fits')
img[np.isnan(img)] = 0

plt.imshow(img,norm=LogNorm(vmin=np.nanmin(img[img != 0]),vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS434_3kpc.pdf')
plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 133.8204148294566  64.4083221617287
# CRPIX : 2108.5  2121.5
# CD1_1 CD1_2  : 1.11606843645179e-05  -8.2668227925549e-06
# CD2_1 CD2_2  : -8.2668227925549e-06  -1.1160684364517e-05
# NAXIS : 4217  4243
# 3

# %%
main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/MRK507_drz.fits',0.05500,267.159564,68.7045251,'deg','BASS924_50kpc',phys_size=50)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS924_50kpc.fits')
img[np.isnan(img)] = 0

plt.imshow(img,norm=LogNorm(vmin=0.01,vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS924_50kpc.pdf')
plt.close()


main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/MRK507_drz.fits',0.05500,267.159564,68.7045251,'deg','BASS924_5kpc',phys_size=5)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS924_5kpc.fits')
img[np.isnan(img)] = 0

plt.imshow(img,norm=LogNorm(vmin=np.nanmin(img[img != 0]),vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS924_5kpc.pdf')
plt.close()


main('/Users/connorauge/Research/BASS/HST_GalaxyZoo/OpticalImages/MRK507_drz.fits',0.05500,267.159564,68.7045251,'deg','BASS924_3kpc',phys_size=3)
img = io.fits.getdata('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS924_3kpc.fits')
img[np.isnan(img)] = 0

plt.imshow(img,norm=LogNorm(vmin=np.nanmin(img[img != 0]),vmax=np.nanmax(img)),cmap='gray')
# plt.colorbar()
plt.savefig('/Users/connorauge/Research/BASS/HST_GalaxyZoo/cutouts/BASS924_3kpc.pdf')
plt.close()
# Out:
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 267.1390058752483  68.69188852701876
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.1307299662826e-05  8.06512299366532e-06
# CD2_1 CD2_2  : 8.06512299366532e-06  1.13072996628263e-05
# NAXIS : 4215  4246
# 50
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 267.1390058752483  68.69188852701876
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.1307299662826e-05  8.06512299366532e-06
# CD2_1 CD2_2  : 8.06512299366532e-06  1.13072996628263e-05
# NAXIS : 4215  4246
# 5
# WCS Keywords
#
# Number of WCS axes: 2
# CTYPE : 'RA---TAN'  'DEC--TAN'
# CRVAL : 267.1390058752483  68.69188852701876
# CRPIX : 2107.5  2123.0
# CD1_1 CD1_2  : -1.1307299662826e-05  8.06512299366532e-06
# CD2_1 CD2_2  : 8.06512299366532e-06  1.13072996628263e-05
# NAXIS : 4215  4246
# 3
